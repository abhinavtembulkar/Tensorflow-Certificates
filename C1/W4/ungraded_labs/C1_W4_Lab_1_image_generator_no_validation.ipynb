# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C1/W4/ungraded_labs/C1_W4_Lab_1_image_generator_no_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training with ImageDataGenerator
#
# In this lab, you will build a train a model on the [Horses or Humans](https://www.tensorflow.org/datasets/catalog/horses_or_humans) dataset. This contains over a thousand images of horses and humans with varying poses and filesizes. You will use the [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) class to prepare this dataset so it can be fed to a convolutional neural network.
#
# **IMPORTANT NOTE:** This notebook is designed to run as a Colab. Running it on your local machine might result in some of the code blocks throwing errors.

# %% [markdown]
# Run the code below to download the compressed dataset `horse-or-human.zip`.

# %%
! brew install wget
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:d783cbeb6e6ef0d71c0b442317b54554370decd6fac66bf2d4938c07a63f67be
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.1.4.arm64_big_sur.bottle.tar.gz
# ==> Homebrew collects anonymous analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics have been recorded yet (nor will be during this `brew` run).
#
# ==> homebrew/core is old and unneeded, untapping to save space...
# Untapping homebrew/core...
# Untapped 3 commands and 6451 formulae (6,829 files, 680.9MB).
# ==> Downloading https://formulae.brew.sh/api/formula_tap_migrations.jws.json
# ######################################################################### 100.0%
# ==> Auto-updated Homebrew!
# Updated 4 taps (homebrew/services, mongodb/brew, homebrew/core and homebrew/cask).
# ==> New Formulae
# abi3audit                                mongodb/brew/mongodb-mongocryptd@6.0
# access                                   mtbl
# action-validator                         mvfst
# ada-url                                  mvt
# adb-enhanced                             mysql-client@8.0
# aerleon                                  mysql@8.0
# aftman                                   neonctl
# ain                                      nerdfix
# alass                                    netlistsvg
# ali                                      nexttrace
# amass                                    node@20
# amber                                    noir
# ansible@7                                notation
# ansible@8                                ntbtls
# apify-cli                                ntfy
# apkleaks                                 numbat
# apko                                     nvimpager
# apprise                                  ocaml@4
# appstream                                ollama
# ares                                     onionprobe
# argc                                     open-simh
# argparse                                 openfga
# arjun                                    opensca-cli
# arm-none-eabi-binutils                   opentofu
# arm-none-eabi-gcc                        orbiton
# arm-none-eabi-gdb                        orbuculum
# asitop                                   orcania
# asn                                      ord
# asnmap                                   orogene
# ast-grep                                 osctrl-cli
# ata                                      oslo
# auditwheel                               pan
# authz0                                   patat
# aws-amplify                              patch-package
# awscli-local                             pciutils
# bacon                                    pdfalyzer
# badkeys                                  pdfrip
# bandicoot                                perl-xml-parser
# bao                                      pgrok
# bashate                                  php@8.2
# bashunit                                 phylum-cli
# bazel-diff                               pixi
# bazel-remote                             plog
# bbot                                     pmix
# bfs                                      pocketbase
# bilix                                    poke
# biodiff                                  pop
# biome                                    postgresql@16
# bkcrack                                  powerlevel10k
# blades                                   presenterm
# blake3                                   prettierd
# blink                                    procps@3
# bob                                      protobuf@21
# bomber                                   proxify
# boolector                                proxygen
# botan@2                                  pter
# bounceback                               purr
# bozohttpd                                pwned
# build2                                   pylyzer
# caracal                                  pypy3.10
# cargo-all-features                       pypy3.9
# cargo-auditable                          pyspelling
# cargo-binstall                           pystring
# cargo-binutils                           python-abseil
# cargo-deps                               python-anytree
# cargo-docset                             python-argcomplete
# cargo-generate                           python-asn1crypto
# cargo-sweep                              python-attrs
# cariddi                                  python-boto3
# cbonsai                                  python-botocore
# cdi                                      python-brotli
# cdxgen                                   python-cachetools
# certgraph                                python-certifi
# certsync                                 python-chardet
# cf2tf                                    python-charset-normalizer
# cfripper                                 python-cli-helpers
# chainloop-cli                            python-click
# chainsaw                                 python-colorama
# changie                                  python-configargparse
# chaoskube                                python-configobj
# charls                                   python-cryptography
# chatblade                                python-cycler
# checkdmarc                               python-dateutil
# cherrybomb                               python-dicttoxml
# chisel-tunnel                            python-distlib
# cidr                                     python-distro
# cliam                                    python-docopt
# clive                                    python-filelock
# cloud-sql-proxy                          python-flit-core
# cloudfox                                 python-gdbm@3.12
# cloudlist                                python-hatch-fancy-pypi-readme
# cloudsplaining                           python-hatch-vcs
# codelimit                                python-hatchling
# coder                                    python-idna
# colmap                                   python-jinja
# conda-lock                               python-jmespath
# convco                                   python-json5
# core-lightning                           python-kiwisolver
# couchbase-shell                          python-lxml
# counts                                   python-magic
# cppinsights                              python-mako
# crabz                                    python-markdown-it-py
# crunchy-cli                              python-markupsafe
# cryptopp                                 python-matplotlib
# crystalline                              python-mdurl
# csprecon                                 python-mpmath
# ctpv                                     python-msgpack
# cyclonedx-gomod                          python-mutagen
# cyclonedx-python                         python-networkx
# cycode                                   python-oauthlib
# czkawka                                  python-openapi3
# daktilo                                  python-packaging
# dalfox                                   python-pathspec
# dcp                                      python-pbr
# ddns-go                                  python-platformdirs
# debugbreak                               python-pluggy
# der-ascii                                python-ply
# devcontainer                             python-prompt-toolkit
# dezoomify-rs                             python-psutil
# dicebear                                 python-pycurl
# diffoci                                  python-pyparsing
# direwolf                                 python-pyproject-hooks
# dnsrobocert                              python-pytz
# dockerfile-language-server               python-regex
# dockly                                   python-requests
# dolphie                                  python-requests-oauthlib
# doppler                                  python-rich
# dotter                                   python-s3transfer
# dovi_tool                                python-setuptools
# driftwood                                python-setuptools-scm
# drogon                                   python-sympy
# dtools                                   python-termcolor
# dysk                                     python-tk@3.12
# dzr                                      python-toml
# eatmemory                                python-trove-classifiers
# ebook2cw                                 python-urllib3
# elfx86exts                               python-wcwidth
# erg                                      python-websocket-client
# erlang@25                                python-xlsxwriter
# espflash                                 python@3.12
# eza                                      qalculate-qt
# faircamp                                 qbittorrent-cli
# falco                                    quantum++
# falcoctl                                 quictls
# fastgron                                 rapidfuzz-cpp
# favirecon                                raven
# feishu2md                                rdap
# ffmpeg@5                                 recoverpy
# flyscrape                                redress
# forgit                                   redwax-tool
# form                                     reflex
# frozen                                   regclient
# fuc                                      rekor-cli
# fw                                       resvg
# fwupd                                    retire
# gat                                      retry
# gcc@12                                   richgo
# gdrive@2                                 rio
# geoip2fast                               riscv64-elf-binutils
# getmail6                                 riscv64-elf-gcc
# gffread                                  riscv64-elf-gdb
# ggshield                                 risor
# ghc@9.4                                  roadrunner
# ghc@9.6                                  roblox-ts
# gickup                                   rojo
# gismo                                    rpmspectool
# git-big-picture                          ruff-lsp
# git-credential-oauth                     ruler
# git-mediate                              runme
# git-tools                                rye
# gitea                                    s3scanner
# gitoxide                                 sad
# gitsign                                  saf-cli
# gittuf                                   safeint
# glbinding@2                              sbom-tool
# go@1.20                                  scarb
# goread                                   scikit-image
# goresym                                  scilla
# gossip                                   scip
# gotestsum                                scoutsuite
# gotestwaf                                scrapy
# gotpm                                    sh4d0wup
# govulncheck                              shell2http
# gptline                                  shellspec
# graphqlviz                               shodan
# grpc@1.54                                shub
# grype                                    shuffledns
# haiti                                    shush
# hck                                      sickchill
# helidon                                  sigma-cli
# hex                                      signmykey
# hivex                                    sigstore
# hoverfly                                 skate
# hyfetch                                  sloth
# img2pdf                                  slsa-verifier
# imgdiet                                  smlfmt
# imgdiff                                  snakeviz
# immer                                    snyk-cli
# incus                                    solo2-cli
# instaloader                              solr@8.11
# intercept                                spacer
# invoice                                  spglib
# iocextract                               spicetify-cli
# ittapi                                   spidermonkey@91
# jet                                      spotify_player
# joshuto                                  sqlfmt
# jprq                                     sqlpage
# jr                                       sqlsmith
# jsign                                    squealer
# jsmn                                     squiid
# json2ts                                  ssh-mitm
# judy                                     sshportal
# jupyter-r                                ssocr
# karmadactl                               staq
# katana                                   strip-nondeterminism
# kew                                      surelog
# killport                                 svlint
# kitex                                    svls
# kor                                      swift-outdated
# kosli-cli                                tailspin
# lager                                    tailwindcss
# ldeep                                    tailwindcss-language-server
# ldid-procursus                           talhelper
# legitify                                 telegram-downloader
# libabigail                               tern
# libclc                                   terraform-graph-beautifier
# libconfini                               terraform-local
# libcyaml                                 terragrunt-atlantis-config
# libdicom                                 texttest
# libdivsufsort                            tf-profile
# libdpp                                   three-body
# libecpint                                thriftgo
# libfastjson                              tlrc
# libgedit-gtksourceview                   toxiproxy
# libgit2@1.6                              tpm
# libimobiledevice-glue                    trafilatura
# libint                                   trufflehog
# libjcat                                  trzsz-ssh
# libjuice                                 typical
# liblxi                                   tzdiff
# libmapper                                udp2raw-multiplatform
# libmediainfo                             uffizzi
# libnghttp3                               uhdm
# libomemo-c                               uncover
# libpaho-mqtt                             urlfinder
# libpanel                                 uvicorn
# libsail                                  vet
# libshumate                               virtctl
# libversion                               virtualfish
# libvisual                                votca
# libvisual-plugins                        vulkan-extensionlayer
# libvisual-projectm                       vulkan-tools
# libxmlb                                  vulkan-utility-libraries
# libzen                                   vulkan-validationlayers
# llm                                      vulsio-gost
# llvm@16                                  vunnel
# lowdown                                  vvdec
# lpeg                                     vvenc
# lr                                       wally
# ls-lint                                  web-ext
# lune                                     webpod
# lxi-tools                                wget2
# mailpit                                  whisper-cpp
# mariadb@10.11                            witness
# mariadb@11.0                             woodpecker-cli
# mariadb@11.1                             woof-doom
# massdriver                               wormhole-william
# mediamtx                                 wpscan
# medusa                                   wtfis
# melange                                  wxlua
# memray                                   wzprof
# mentat                                   xbyak
# meson-python                             xe
# meta-package-manager                     xeol
# mfem                                     xlsxio
# mgis                                     xnvme
# millet                                   yamlfmt
# minder                                   yatas
# minigraph                                yazi
# mjml                                     yder
# mods                                     yyjson
# modsecurity                              zchunk
# modsurfer                                zix
# mongodb/brew/mongodb-community@6.0       zrok
# mongodb/brew/mongodb-enterprise@6.0      zug
# ==> New Casks
# 1kc-razer
# 4k-video-downloaderplus
# active-trader-pro
# affine
# aifun
# akuity
# amie
# anka-build-cloud-controller
# anka-build-cloud-registry
# apidog
# apple-hewlett-packard-printer-drivers
# applite
# asix-ax88179
# audiocupcake
# ava
# batchoutput-pdf
# batteryboi
# bepo
# bezel
# blockstream-green
# bloop
# bluos-controller
# bookletcreator
# bose-updater
# brickstore
# brightintosh
# browser-deputy
# btp
# caldigit-docking-utility
# caldigit-thunderbolt-charging
# cameracontroller
# canon-eos-utility
# capacities
# cardo-update
# chainner
# chatall
# chatbox
# cilicon
# clibor
# clickhouse
# clinq
# clop
# cloudnet
# codewhisperer
# command-x
# commandpost
# concept2-utility
# copilot
# craft
# creality-print
# creative
# crystalfetch
# dadroit-json-viewer
# ddpm
# deskpad
# deveco-studio
# devpod
# devtunnel
# dintch
# displaylink
# dockx
# douyin-chat
# drata-agent
# draw-things
# droidcam-obs
# dropbox-dash
# dropshelf
# dymo-label
# ecodms-client
# effect-house
# egovframedev
# elektron-overbridge
# elektron-transfer
# elgato-camera-hub
# elgato-control-center
# elgato-game-capture-hd
# elgato-stream-deck
# elgato-video-capture
# elgato-wave-link
# energiza
# engine-dj
# ente
# entry
# eobcanka
# eset-cyber-security
# eu
# eusamanager
# expo-orbit
# fedistar
# filemonitor
# finbar
# firefly-shimmer
# flexoptix
# floorp
# focusrite-control
# focusrite-control-2
# focusrite-saffire-mixcontrol
# font-finagler
# fossa
# fractal-bot
# frappe-books
# free-podcast-transcription
# ftdi-vcp-driver
# fujitsu-scansnap-home
# garmin-basecamp
# garmin-express
# genesys-cloud
# git-credential-manager
# gitkraken-cli
# glaze
# graalvm-jdk
# greenery
# grs-bluewallet
# gstreamer-development
# gstreamer-runtime
# gutenprint
# hapigo
# hdhomerun
# herd
# heynote
# hhkb
# hides
# hoppscotch
# hovrly
# hp-easy-admin
# hp-easy-start
# hypercal
# iem-plugin-suite
# imazing-profile-editor
# insta360-studio
# jabra-direct
# jazz2-resurrection
# json-viewer
# jukebox
# karafun
# keyboard-cowboy
# keyclu
# keymapp
# kiibohd-configurator
# konica-minolta-bizhub-c750i-driver
# konica-minolta-bizhub-c759-c658-c368-c287-c3851-driver
# kreya
# kuaitie
# lasso
# lg-onscreen-control
# libndi
# linn-konfig
# llamachat
# lm-studio
# lo-rain
# logi-options-plus
# logitech-camera-settings
# logitech-g-hub
# logitech-options
# logitune
# loupedeck
# low-profile
# luniistore
# lw-scanner
# maa
# macgpt
# macwhisper
# mdb-accdb-viewer
# mediamate
# meld-studio
# metamer
# mindmac
# mitmproxy
# modrinth
# monotype
# motu-m-series
# mumu-x
# music-decoy
# music-miniplayer
# music-remote
# music-widget
# mutedeck
# muyu
# mycard
# navigraph-charts
# navigraph-simlink
# nordic-nrf-command-line-tools
# notes-better
# nvs
# nx-studio
# obsbot-webcam
# october
# ok-json
# openbb-terminal
# openrocket
# orka3
# ovito
# ovito-pro
# pallotron-yubiswitch
# paulxstretch
# philips-hue-sync
# piclist
# picoscope
# pieces
# pieces-os
# piphero
# playdate-mirror
# poe
# pololu-avr-programmer-v2
# processmonitor
# prolific-pl2303
# proton-drive
# proxy-audio-device
# qflipper
# qmk-toolbox
# reader
# recipeui
# red-canary-mac-monitor
# reminders-menubar
# replay
# reqable
# rewind
# ricoh-theta
# rio
# rippling
# ripx
# roam
# rode-central
# rode-connect
# routine
# rustrover
# sakura
# saleae-logic
# salt
# samsung-portable-ssd-t7
# score
# screen-studio
# screens-assist
# segger-jlink
# senabluetoothdevicemanager
# sf
# sfm
# shattered-pixel-dungeon
# showmeyourhotkeys
# shureplus-motiv
# silicon-labs-vcp-driver
# simple-web-server
# simplex
# skiff
# smooze-pro
# songkong
# sonos
# sony-ps-remote-play
# space-capsule
# spacedrive
# sparkplate
# spundle
# stash
# steelseries-engine
# steelseries-gg
# submariner
# synology-cloud-station-backup
# synology-drive
# synology-photo-station-uploader
# synology-surveillance-station-client
# synologyassistant
# tachidesk-sorayomi
# telegram-a
# ths
# timemachinestatus
# tiptoi-manager
# to-audio-converter
# toshiba-color-mfp
# truhu
# tuist
# tunetag
# twelite-stage
# ubiquiti-unifi-controller
# uhk-agent
# updf
# vimcal
# viso
# voicepeak
# volta
# wacom-tablet
# wave
# wch-ch34x-usb-serial-driver
# wetype
# whisky
# wiso-steuer-2022
# wiso-steuer-2023
# wiso-steuer-2024
# writerside
# xact
# xiaomi-cloud
# xliff-editor
# xsplit-vcam
# xtool-creative-space
# yealink-meeting
# yubico-authenticator
# yubico-yubikey-manager
# zsa-wally
# zspace
# zui
#
# You have 16 outdated formulae installed.
# ==> Downloading https://formulae.brew.sh/api/cask_tap_migrations.jws.json
# ######################################################################### 100.0%
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.4
# ######################################################################### 100.0%
# ==> Fetching dependencies for wget: libunistring, gettext, libidn2, ca-certificates and openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.1
# ######################################################################### 100.0%
# ==> Fetching libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:6d499
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.22.4
# ######################################################################### 100.0%
# ==> Fetching gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:43d00547f4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4_1-1
# ######################################################################### 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:d79edd6e4f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2023-
# ######################################################################### 100.0%
# ==> Fetching ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:5c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.2.0_1
# ######################################################################### 100.0%
# ==> Fetching openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:6519a6ff
# ######################################################################### 100.0%
# ==> Fetching wget
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:47cb2b77bcb48
# ######################################################################### 100.0%
# ==> Installing dependencies for wget: libunistring, gettext, libidn2, ca-certificates and openssl@3
# ==> Installing wget dependency: libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.1
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/a34801f1ad5800ba51b2b3951d82a913ccf0641982f86b02df2f0aa182535055--libunistring-1.1.bottle_manifest.json
# ==> Pouring libunistring--1.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.1: 56 files, 5.0MB
# ==> Installing wget dependency: gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.22.4
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/3ceb9457127eaa7378dd80ed256098ffb391e2350069becb25cfe2a14f0b7d6d--gettext-0.22.4.bottle_manifest.json
# ==> Pouring gettext--0.22.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gettext/0.22.4: 2,042 files, 24.3MB
# ==> Installing wget dependency: libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4_1-1
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/03ad193177f4e7d05ee2ed19a455028cb5fbf7ea1a812d88f18f5e9e8b4a4d43--libidn2-2.3.4_1-1.bottle_manifest.json
# ==> Pouring libidn2--2.3.4_1.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/libidn2/2.3.4_1: 79 files, 1MB
# ==> Installing wget dependency: ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2023-
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/13aa86e429e05d02a76005d1881eaf625091a5ac4dc7d7674c706d12ba48796a--ca-certificates-2023-12-12.bottle_manifest.json
# ==> Pouring ca-certificates--2023-12-12.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2023-12-12: 3 files, 226.7KB
# ==> Installing wget dependency: openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.2.0_1
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/8e5415de690efd057f74775ab4b808fed9a50bf29c34ee9cb52118d189ef73a9--openssl@3-3.2.0_1.bottle_manifest.json
# ==> Pouring openssl@3--3.2.0_1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openssl@3/3.2.0_1: 6,805 files, 31.9MB
# ==> Installing wget
# ==> Pouring wget--1.21.4.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/wget/1.21.4: 91 files, 4.4MB
# ==> Running `brew cleanup wget`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Warning: The following dependents of upgraded formulae are outdated but will not
# be upgraded because they are not bottled:
#   mongodb-community
# ==> Upgrading 6 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# git 2.40.0 -> 2.43.0, openssl@1.1 1.1.1t -> 1.1.1w, node@16 16.19.1 -> 16.20.2, mongosh 1.8.0 -> 2.1.1, node 19.8.1 -> 21.5.0, redis 7.0.9 -> 7.2.3
# Warning: openssl@1.1 has been deprecated because it is not supported upstream!
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1w
# ######################################################################### 100.0%
# Warning: node@16 has been deprecated because it is not supported upstream!
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/16/manifests/16.20.2-1
# ######################################################################### 100.0%
# ==> Fetching dependencies for node@16: brotli, c-ares, icu4c, libnghttp2 and libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# ######################################################################### 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:2a95140d611
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/manifests/1.24.0
# ######################################################################### 100.0%
# ==> Fetching c-ares
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/blobs/sha256:f9345a17bd9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/73.2
# ######################################################################### 100.0%
# ==> Fetching icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:734c09d5285c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.58.0
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:0aea68b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.47.0
# ######################################################################### 100.0%
# ==> Fetching libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/blobs/sha256:8ec04556c7b8
# ######################################################################### 100.0%
# ==> Fetching node@16
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/16/blobs/sha256:27070fb927
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/git/manifests/2.43.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/manifests/21.5.0
# ######################################################################### 100.0%
# ==> Fetching node
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/blobs/sha256:1d358e09d583f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mongosh/manifests/2.1.1
# ######################################################################### 100.0%
# ==> Fetching mongosh
# ==> Downloading https://ghcr.io/v2/homebrew/core/mongosh/blobs/sha256:310782125c
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/redis/manifests/7.2.3
# ######################################################################### 100.0%
# ==> Upgrading node@16
#   16.19.1 -> 16.20.2
#
# ==> Installing dependencies for node@16: brotli, c-ares, icu4c, libnghttp2 and libuv
# ==> Installing node@16 dependency: brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-1
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/565098509cdfa90593ec9a41b41239f073843f88caed60ddaa3e6194ac4defda--brotli-1.1.0-1.bottle_manifest.json
# ==> Pouring brotli--1.1.0.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/brotli/1.1.0: 24 files, 1013.4KB
# ==> Installing node@16 dependency: c-ares
# ==> Downloading https://ghcr.io/v2/homebrew/core/c-ares/manifests/1.24.0
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/8ee78cfc40cf97702e0b33525d8c409d8ad8eb8d7677fa87226376ebf8823adb--c-ares-1.24.0.bottle_manifest.json
# ==> Pouring c-ares--1.24.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/c-ares/1.24.0: 156 files, 1MB
# ==> Installing node@16 dependency: icu4c
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/73.2
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/2e5082de52a2c85ae665e51f8d0de0651611397cb02f4b4e2bb37898ba52a629--icu4c-73.2.bottle_manifest.json
# ==> Pouring icu4c--73.2.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/icu4c/73.2: 268 files, 80.2MB
# ==> Installing node@16 dependency: libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.58.0
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/9b2081d73959d4308c84740344d5f8169bbb9125dd76d20a71556a11a0171253--libnghttp2-1.58.0.bottle_manifest.json
# ==> Pouring libnghttp2--1.58.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libnghttp2/1.58.0: 13 files, 739KB
# ==> Installing node@16 dependency: libuv
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.47.0
# Already downloaded: /Users/future/Library/Caches/Homebrew/downloads/bfee09d0f61c35b1a86c5b7a0f6b2f9e0a8b18a81bbd065f6eea7054b543f3ea--libuv-1.47.0.bottle_manifest.json
# ==> Pouring libuv--1.47.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libuv/1.47.0: 19 files, 1.1MB
# ==> Installing node@16
# ==> Pouring node@16--16.20.2.arm64_sonoma.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/node@16/16.20.2: 1,890 files, 43.5MB
# ==> Running `brew cleanup node@16`...
# Removing: /opt/homebrew/Cellar/node@16/16.19.1... (1,892 files, 47.8MB)
# ==> Upgrading node
#   19.8.1 -> 21.5.0
#
# ==> Pouring node--21.5.0.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/node/21.5.0: 2,233 files, 63.2MB
# ==> Running `brew cleanup node`...
# Removing: /opt/homebrew/Cellar/node/19.8.1... (2,357 files, 54.9MB)
# ==> Upgrading mongosh
#   1.8.0 -> 2.1.1
#
# ==> Pouring mongosh--2.1.1.arm64_sonoma.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mongosh/2.1.1: 10,384 files, 47.4MB
# ==> Running `brew cleanup mongosh`...
# Removing: /opt/homebrew/Cellar/mongosh/1.8.0... (8,177 files, 40.8MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /opt/homebrew/Cellar/brotli/1.0.9... (25 files, 2.3MB)
# Removing: /opt/homebrew/Cellar/c-ares/1.19.0... (87 files, 675.9KB)
# Removing: /opt/homebrew/Cellar/ca-certificates/2023-01-10... (3 files, 216.9KB)
# Removing: /opt/homebrew/Cellar/gettext/0.21.1... (1,983 files, 20.9MB)
# Removing: /opt/homebrew/Cellar/icu4c/72.1... (263 files, 78.4MB)
# Removing: /opt/homebrew/Cellar/libnghttp2/1.52.0... (13 files, 731.5KB)
# Removing: /opt/homebrew/Cellar/libuv/1.44.2... (51 files, 3.5MB)
# Pruned 0 symbolic links and 4 directories from /opt/homebrew

# %%
# !wget https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Out:
# --2023-12-26 19:36:59--  https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.206.123, 142.250.206.187, 142.250.194.91, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.206.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M  13.9MB/s    in 11s
#
# 2023-12-26 19:37:11 (12.5 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %% [markdown]
# You can then unzip the archive using the [zipfile](https://docs.python.org/3/library/zipfile.html) module.

# %%
import zipfile

# Unzip the dataset
local_zip = './horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./horse-or-human')
zip_ref.close()

# %% [markdown]
# The contents of the .zip are extracted to the base directory `./horse-or-human`, which in turn each contain `horses` and `humans` subdirectories.
#
# In short: The training set is the data that is used to tell the neural network model that 'this is what a horse looks like' and 'this is what a human looks like'.
#
# One thing to pay attention to in this sample: We do not explicitly label the images as horses or humans. You will use the ImageDataGenerator API instead -- and this is coded to automatically label images according to the directory names and structure. So, for example, you will have a 'training' directory containing a 'horses' directory and a 'humans' one. `ImageDataGenerator` will label the images appropriately for you, reducing a coding step.
#
# You can now define each of these directories:

# %%
import os

# Directory with our training horse pictures
train_horse_dir = os.path.join('./horse-or-human/horses')

# Directory with our training human pictures
train_human_dir = os.path.join('./horse-or-human/humans')

# %% [markdown]
# Now see what the filenames look like in the `horses` and `humans` training directories:

# %%
train_horse_names = os.listdir(train_horse_dir)
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# ['horse43-5.png', 'horse06-5.png', 'horse20-6.png', 'horse04-7.png', 'horse41-7.png', 'horse22-4.png', 'horse19-2.png', 'horse24-2.png', 'horse37-8.png', 'horse02-1.png']
# ['human17-22.png', 'human10-17.png', 'human10-03.png', 'human07-27.png', 'human09-22.png', 'human05-22.png', 'human02-03.png', 'human02-17.png', 'human15-27.png', 'human12-12.png']

# %% [markdown]
# You can also find out the total number of horse and human images in the directories:

# %%
print('total training horse images:', len(os.listdir(train_horse_dir)))
print('total training human images:', len(os.listdir(train_human_dir)))
# Out:
# total training horse images: 500
# total training human images: 527

# %% [markdown]
# Now take a look at a few pictures to get a better sense of what they look like. First, configure the `matplotlib` parameters:

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %% [markdown]
# Now, display a batch of 8 horse and 8 human pictures. You can rerun the cell to see a fresh batch each time:

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_horse_pix = [os.path.join(train_horse_dir, fname) 
                for fname in train_horse_names[pic_index-8:pic_index]]
next_human_pix = [os.path.join(train_human_dir, fname) 
                for fname in train_human_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_horse_pix+next_human_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Building a Small Model from Scratch
#
# Now you can define the model architecture that you will train.
#
# Step 1 will be to import tensorflow.

# %%
import tensorflow as tf

# %% [markdown]
# You then add convolutional layers as in the previous example, and flatten the final result to feed into the densely connected layers. Note that because this is a two-class classification problem, i.e. a *binary classification problem*, you will end your network with a [*sigmoid* activation](https://wikipedia.org/wiki/Sigmoid_function). This makes the output value of your network a single scalar between 0 and 1, encoding the probability that the current image is class 1 (as opposed to class 0).

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 300x300 with 3 bytes color
    # This is the first convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The third convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fourth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # The fifth convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# You can review the network architecture and the output shapes with `model.summary()`.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 149, 149, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1704097 (6.50 MB)
# Trainable params: 1704097 (6.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# The "output shape" column shows how the size of your feature map evolves in each successive layer. As you saw in an earlier lesson, the convolution layers removes the outermost pixels of the image, and each pooling layer halves the dimensions.

# %% [markdown]
# Next, you'll configure the specifications for model training. You will train the model with the [`binary_crossentropy`](https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy) loss because it's a binary classification problem, and the final activation is a sigmoid. (For a refresher on loss metrics, see this [Machine Learning Crash Course](https://developers.google.com/machine-learning/crash-course/descending-into-ml/video-lecture).) You will use the `rmsprop` optimizer with a learning rate of `0.001`. During training, you will want to monitor classification accuracy.
#
# **NOTE**: In this case, using the [RMSprop optimization algorithm](https://wikipedia.org/wiki/Stochastic_gradient_descent#RMSProp) is preferable to [stochastic gradient descent](https://developers.google.com/machine-learning/glossary/#SGD) (SGD), because RMSprop automates learning-rate tuning for us. (Other optimizers, such as [Adam](https://wikipedia.org/wiki/Stochastic_gradient_descent#Adam) and [Adagrad](https://developers.google.com/machine-learning/glossary/#AdaGrad), also automatically adapt the learning rate during training, and would work equally well here.)

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.

# %% [markdown]
# ### Data Preprocessing
#
# Next step is to set up the data generators that will read pictures in the source folders, convert them to `float32` tensors, and feed them (with their labels) to the model. You'll have one generator for the training images and one for the validation images. These generators will yield batches of images of size 300x300 and their labels (binary).
#
# As you may already know, data that goes into neural networks should usually be normalized in some way to make it more amenable to processing by the network (i.e. It is uncommon to feed raw pixels into a ConvNet.) In this case, you will preprocess the images by normalizing the pixel values to be in the `[0, 1]` range (originally all values are in the `[0, 255]` range).
#
# In Keras, this can be done via the `keras.preprocessing.image.ImageDataGenerator` class using the `rescale` parameter. This `ImageDataGenerator` class allows you to instantiate generators of augmented image batches (and their labels) via `.flow(data, labels)` or `.flow_from_directory(directory)`.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        './horse-or-human/',  # This is the source directory for training images
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=128,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')
# Out:
# Found 1027 images belonging to 2 classes.

# %% [markdown]
# ### Training
#
# You can start training for 15 epochs -- this may take a few minutes to run.
#
# Do note the values per epoch.
#
# The `loss` and `accuracy` are great indicators of progress in training. `loss` measures the current model prediction against the known labels, calculating the result. `accuracy`, on the other hand, is the portion of correct guesses.

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=15,
      verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 14s 2s/step - loss: 0.7196 - accuracy: 0.5184
# Epoch 2/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6952 - accuracy: 0.5829
# Epoch 3/15
# 8/8 [==============================] - 13s 2s/step - loss: 0.6482 - accuracy: 0.6885
# Epoch 4/15
# 8/8 [==============================] - 14s 2s/step - loss: 0.5912 - accuracy: 0.6830
# Epoch 5/15
# 8/8 [==============================] - 14s 2s/step - loss: 0.4179 - accuracy: 0.8331
# Epoch 6/15
# 8/8 [==============================] - 15s 2s/step - loss: 1.0315 - accuracy: 0.6874
# Epoch 7/15
# 8/8 [==============================] - 14s 2s/step - loss: 0.3333 - accuracy: 0.8754
# Epoch 8/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.1633 - accuracy: 0.9444
# Epoch 9/15
# 8/8 [==============================] - 17s 2s/step - loss: 0.1210 - accuracy: 0.9551
# Epoch 10/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.7481 - accuracy: 0.7786
# Epoch 11/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.2690 - accuracy: 0.9066
# Epoch 12/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.1740 - accuracy: 0.9355
# Epoch 13/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.0821 - accuracy: 0.9722
# Epoch 14/15
# 8/8 [==============================] - 17s 2s/step - loss: 0.0295 - accuracy: 0.9912
# Epoch 15/15
# 8/8 [==============================] - 15s 2s/step - loss: 0.0119 - accuracy: 0.9956

# %% [markdown]
# ### Model Prediction
#
# Now take a look at actually running a prediction using the model. This code will allow you to choose 1 or more files from your file system, upload them, and run them through the model, giving an indication of whether the object is a horse or a human.
#
# _**Note:** Old versions of the Safari browser might have compatibility issues with the code block below. If you get an error after you select the images(s) to upload, you can consider updating your browser to the latest version. If not possible, please comment out or skip the code block below, uncomment the next code block and run it._

# %%
## NOTE: If you are using Safari and this cell throws an error,
## please skip this block and run the next one instead.

import numpy as np
from google.colab import files
from tensorflow.keras.utils import load_img, img_to_array

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = load_img(path, target_size=(300, 300))
  x = img_to_array(img)
  x /= 255
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
    
  if classes[0]>0.5:
    print(fn + " is a human")
  else:
    print(fn + " is a horse")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 5
#       1 ## NOTE: If you are using Safari and this cell throws an error,
#       2 ## please skip this block and run the next one instead.
#       4 import numpy as np
# ----> 5 from google.colab import files
#       6 from tensorflow.keras.utils import load_img, img_to_array
#       8 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# If you're using Safari and the cell above throws an error, you will need to upload the images(s) manually in their workspace.
#
# Instructions on how to upload image(s) manually in a Colab:
#
# 1. Select the `folder` icon on the left `menu bar`.
# 2. Click on the `folder with an arrow pointing upwards` named `..`
# 3. Click on the `folder` named `tmp`.
# 4. Inside of the `tmp` folder, `create a new folder` called `images`. You'll see the `New folder` option by clicking the `3 vertical dots` menu button next to the `tmp` folder.
# 5. Inside of the new `images` folder, upload an image(s) of your choice, preferably of either a horse or a human. Drag and drop the images(s) on top of the `images` folder.
# 6. Uncomment and run the code block below.

# %%
# # CODE BLOCK FOR OLD VERSIONS OF SAFARI

# import numpy as np
# from tensorflow.keras.utils import load_img, img_to_array
# import os

# images = os.listdir("/tmp/images")

# print(images)

# for i in images:
#  print()
#  # predicting images
#  path = '/tmp/images/' + i
#  img = load_img(path, target_size=(300, 300))
#  x = img_to_array(img)
#  x /= 255
#  x = np.expand_dims(x, axis=0)

#  images = np.vstack([x])
#  classes = model.predict(images, batch_size=10)
#  print(classes[0])
#  if classes[0]>0.5:
#    print(i + " is a human")
#  else:
#    print(i + " is a horse")

# %% [markdown]
# ### Check random image

# %%
from tensorflow.keras.utils import load_img, img_to_array
from tqdm import tqdm

# %%
img = load_img('../images/horse-man.jpeg', target_size=(300,300))
img = img_to_array(img)
img = img / 255

plt.imshow(img)

# %%
print(img.shape)
# Out:
# (300, 300, 3)

# %%
output = model.predict(img.reshape(1,300,300,3))

if output[0] > 0.5:
    print(output[0]*100,'% Human')
else:
    print((1 - output[0])*100,'% Horse')
# Out:
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 31ms/step
# [99.46637] % Horse

# %% [markdown]
# ### Visualizing Intermediate Representations
#
# To get a feel for what kind of features your CNN has learned, one fun thing to do is to visualize how an input gets transformed as it goes through the model.
#
# You can pick a random image from the training set, and then generate a figure where each row is the output of a layer, and each image in the row is a specific filter in that output feature map. Rerun this cell to generate intermediate representations for a variety of training images.

# %%
import numpy as np
import random
from tensorflow.keras.utils import img_to_array, load_img

# Define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Prepare a random input image from the training set.
horse_img_files = [os.path.join(train_horse_dir, f) for f in train_horse_names]
human_img_files = [os.path.join(train_human_dir, f) for f in train_human_names]
img_path = random.choice(horse_img_files + human_img_files)

img = load_img(img_path, target_size=(300, 300))  # this is a PIL image
x = img_to_array(img)  # Numpy array with shape (300, 300, 3)
x = x.reshape((1,) + x.shape)  # Numpy array with shape (1, 300, 300, 3)

# Scale by 1/255
x /= 255

# Run the image through the network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so you can have them as part of the plot
layer_names = [layer.name for layer in model.layers[1:]]

# Display the representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:

    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map

    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    
    # Tile the images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
    
      # Tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# 1/1 [==============================] - 0s 56ms/step
# /var/folders/kl/11gkxl5x49l9sffk443vsksh0000gq/T/ipykernel_1288/846085612.py:45: RuntimeWarning: invalid value encountered in divide
#   x /= x.std()
# /var/folders/kl/11gkxl5x49l9sffk443vsksh0000gq/T/ipykernel_1288/846085612.py:48: RuntimeWarning: invalid value encountered in cast
#   x = np.clip(x, 0, 255).astype('uint8')

# %% [markdown]
# You can see above how the pixels highlighted turn to increasingly abstract and compact representations, especially at the bottom grid.
#
# The representations downstream start highlighting what the network pays attention to, and they show fewer and fewer features being "activated"; most are set to zero. This is called _representation sparsity_ and is a key feature of deep learning. These representations carry increasingly less information about the original pixels of the image, but increasingly refined information about the class of the image. You can think of a convnet (or a deep network in general) as an information distillation pipeline wherein each layer filters out the most useful features.

# %% [markdown]
# ## Clean Up
#
# You will continue with a similar exercise in the next lab but before that, run the following cell to terminate the kernel and free memory resources:

# %%
from google.colab import runtime
runtime.unassign()
